# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandrashekharRobbi/Convolutional-Neural-Network-or-Neural-Network-with-Tensorflow/blob/main/Regression%20Neural%20Networks/Introduction%20to%20Regression%20Neural%20Network/introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Regression Neural Network
#
# In this noetbook we will be creating the scalar tensors and try to train model and make predictins
# For eg we have X = [4,7,10,13] and y=[14,17,20,23] so the model has to predict the realtion `y = x + 10`
#
# This notebook is just the start of the or we can say basic introduction to our neural networks.

# %%
#import the tensorflow and check the version
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# C:\tensorflow-gpu\env\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2.9.0

# %%
# create features
X = np.arange(-7,15,3)

# Create labeks
y = np.arange(3,25,3)

# visualize the data
plt.scatter(X,y)

# %% [markdown]
# ### Input and output shapes

# %%
# create a demo of the house prediction by using the tensors
tf_details = tf.constant(["bedroom","bathroom","garage"])
tf_houseprice = tf.constant(92543)
tf_details, tf_houseprice
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(), dtype=int32, numpy=92543>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape
# Out:
# ((), ())

# %%
# convert the numpy arrays into the tensors
X = tf.constant(X)
y = tf.constant(y)
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=int32, numpy=array([-7, -4, -1,  2,  5,  8, 11, 14])>,
#  <tf.Tensor: shape=(8,), dtype=int32, numpy=array([ 3,  6,  9, 12, 15, 18, 21, 24])>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %% [markdown]
# ## Steps in modelling with Tensorflow
#
# 1. **Creating a model** - define the input and output layers as well as the hidden layers of a deep learning model.
# 2. **Compiling a model** - define the **loss** function (in other words the function which tells our model how wrong it is) and the **optimizer** (tells our model how to improve the patterns its learning) and **evaluation metrices(what we can use to interpret the performance of our model).
# 3. **Fitting a model** - letting the model to try to find patterns between X & y (features and labels)

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# Compile a model
model.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.SGD(),
             metrics=["mae"])

# fit a model
model.fit(tf.expand_dims(X,axis=-1),y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/10
# 1/1 [==============================] - 0s 8ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/10
# 1/1 [==============================] - 0s 0s/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/10
# 1/1 [==============================] - 0s 8ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/10
# 1/1 [==============================] - 0s 0s/step - loss: 10.9748 - mae: 10.9748
# Epoch 6/10
# 1/1 [==============================] - 0s 8ms/step - loss: 10.8423 - mae: 10.8423
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 10.7098 - mae: 10.7098
# Epoch 8/10
# 1/1 [==============================] - 0s 4ms/step - loss: 10.5773 - mae: 10.5773
# Epoch 9/10
# 1/1 [==============================] - 0s 8ms/step - loss: 10.4448 - mae: 10.4448
# Epoch 10/10
# 1/1 [==============================] - 0s 8ms/step - loss: 10.3123 - mae: 10.3123

# %%
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=int32, numpy=array([-7, -4, -1,  2,  5,  8, 11, 14])>,
#  <tf.Tensor: shape=(8,), dtype=int32, numpy=array([ 3,  6,  9, 12, 15, 18, 21, 24])>)

# %%
y_preds = model.predict([17])
y_preds
# Out:
# 1/1 [==============================] - 0s 118ms/step
# array([[15.741023]], dtype=float32)

# %%
y_preds - 27
# Out:
# array([[-11.258977]], dtype=float32)

# %% [markdown]
# ### Improving a model
#
# 1. **Creating a model**: By adding more layers , increase the number of hidden layers ( also called neurons) withing each of the hidden layers change each activation function
#
#
# 2. **Compiling a model** : change the optimization function or change the **learning rate** of the optimization function.
#
#
# 3. **Fitting a model**: here we might fit a model for more epochs( leave it training for longer period) or on more data (give the model more data to learn patterns)

# %%
# Let's rebuild the model by changing the number of epochs

# create the model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# comile the model

model.compile(loss=tf.keras.losses.mae,
             optimizer = tf.keras.optimizers.SGD(),
             metrics=["mae"])

# fit the model
model.fit(tf.expand_dims(X,axis=-1),y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 335ms/step - loss: 11.2219 - mae: 11.2219
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.0894 - mae: 11.0894
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.9569 - mae: 10.9569
# Epoch 4/100
# 1/1 [==============================] - 0s 0s/step - loss: 10.8244 - mae: 10.8244
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.6919 - mae: 10.6919
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.5594 - mae: 10.5594
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.4269 - mae: 10.4269
# Epoch 8/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.2944 - mae: 10.2944
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.1619 - mae: 10.1619
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.0294 - mae: 10.0294
# Epoch 11/100
# ...

# %%
# predict the model
model.predict([17])
# Out:
# 1/1 [==============================] - 0s 104ms/step
# array([[29.739855]], dtype=float32)

# %%
# Let's rebuild the model by changing the compile method
# set random seed
tf.random.set_seed(42)
# create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# compile the model
model.compile(loss=tf.keras.losses.mae,
             optimizer= tf.keras.optimizers.Adam(learning_rate=0.00001),
             metrics=["mae"])

# fit the model
model.fit(tf.expand_dims(X,axis=-1),y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 382ms/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.5047 - mae: 11.5047
# Epoch 3/100
# 1/1 [==============================] - 0s 16ms/step - loss: 11.5047 - mae: 11.5047
# Epoch 4/100
# 1/1 [==============================] - 0s 16ms/step - loss: 11.5047 - mae: 11.5047
# Epoch 5/100
# 1/1 [==============================] - 0s 16ms/step - loss: 11.5046 - mae: 11.5046
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.5046 - mae: 11.5046
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.5045 - mae: 11.5045
# Epoch 8/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.5045 - mae: 11.5045
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.5044 - mae: 11.5044
# Epoch 10/100
# 1/1 [==============================] - 0s 16ms/step - loss: 11.5044 - mae: 11.5044
# ...

# %%
# now let's rebuild the model by adding more hidden layers

# set random seed
tf.random.set_seed(42)

# create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(50,activation=None),
    tf.keras.layers.Dense(1)
])

# compile the model
model.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
             metrics=["mae"])

# fit the model
model.fit(tf.expand_dims(X,axis=-1),y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 416ms/step - loss: 13.1820 - mae: 13.1820
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.5071 - mae: 12.5071
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.8279 - mae: 11.8279
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.1425 - mae: 11.1425
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.4484 - mae: 10.4484
# Epoch 6/100
# 1/1 [==============================] - 0s 16ms/step - loss: 9.7426 - mae: 9.7426
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 9.0218 - mae: 9.0218
# Epoch 8/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2826 - mae: 8.2826
# Epoch 9/100
# 1/1 [==============================] - 0s 16ms/step - loss: 7.5221 - mae: 7.5221
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7841 - mae: 6.7841
# Epoch 11/100
# ...

# %%
model.predict([17])
# Out:
# 1/1 [==============================] - 0s 68ms/step
# array([[27.217045]], dtype=float32)

# %% [markdown]
# ### Evaluating a Model

# %%
# Make a bigger dataset
X = tf.range(-100,104,4)
X
# Out:
# <tf.Tensor: shape=(51,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96,  100])>

# %%
# make labels 
y = X + 10 # ( we want these to make our model predict )
y
# Out:
# <tf.Tensor: shape=(51,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106, 110])>

# %%
# Visualize the data
plt.scatter(X,y)

# %%
# split the data into the train and test data
x_train = X[:40]
x_test = X[40:]
y_train = y[:40]
y_test = y[40:]

len(x_train), len(y_train) , len(x_test) , len(y_test)
# Out:
# (40, 40, 11, 11)

# %% [markdown]
# ### Visualize the data

# %%
plt.figure(figsize=(10,6))
# plot training data in red
plt.scatter(x_train, y_train, c="red")
# plot test data in yellow
plt.scatter(x_test, y_test, c="yellow")
# show legend
plt.legend(["Training Data","Testing Data"]);

# %%
# lets build a neural network model by using the training data

# create a random seed
tf.random.set_seed(42)

# create a model 
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10,input_shape=[1],name="input_layer"),
    tf.keras.layers.Dense(1,name="output_layer")
],name="model_1")

# compile a model
model.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
             metrics=["mae"])

# fit a model
model.fit(tf.expand_dims(x_train,axis=-1),y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 8ms/step - loss: 24.7643 - mae: 24.7643
# Epoch 2/100
# 2/2 [==============================] - 0s 8ms/step - loss: 19.0261 - mae: 19.0261
# Epoch 3/100
# 2/2 [==============================] - 0s 8ms/step - loss: 13.5868 - mae: 13.5868
# Epoch 4/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.8756 - mae: 8.8756
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.6328 - mae: 8.6328
# Epoch 6/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.8267 - mae: 10.8267
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.7707 - mae: 11.7707
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.8002 - mae: 11.8002
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.1963 - mae: 11.1963
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.0508 - mae: 10.0508
# Epoch 11/100
# ...

# %%
model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 64ms/step
# array([[ 72.42825 ],
#        [ 76.58671 ],
#        [ 80.74517 ],
#        [ 84.903625],
#        [ 89.06209 ],
#        [ 93.22055 ],
#        [ 97.37901 ],
#        [101.537476],
#        [105.69594 ],
#        [109.854385],
#        [114.01285 ]], dtype=float32)

# %%
y_test
# Out:
# <tf.Tensor: shape=(11,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106, 110])>

# %%
x_test
# Out:
# <tf.Tensor: shape=(11,), dtype=int32, numpy=array([ 60,  64,  68,  72,  76,  80,  84,  88,  92,  96, 100])>

# %%
# visualize the model
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_layer (Dense)         (None, 10)                20
#
#  output_layer (Dense)        (None, 1)                 11
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True)

# %% [markdown]
# ### Visualizing our model predictions

# %%
y_preds = model.predict(x_test)
y_preds
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[ 72.42825 ],
#        [ 76.58671 ],
#        [ 80.74517 ],
#        [ 84.903625],
#        [ 89.06209 ],
#        [ 93.22055 ],
#        [ 97.37901 ],
#        [101.537476],
#        [105.69594 ],
#        [109.854385],
#        [114.01285 ]], dtype=float32)

# %%
# let's create a plotting function
def plot_predictions(train_data=x_train,
                    train_labels=y_train,
                    test_data=x_test,
                    test_labels=y_test,
                    predictions=y_preds):
    """
    Plots training and test data and compares the predictions to the ground data and true labels
    """
    
    plt.figure(figsize=(10,6))
    # plot the training data in red
    plt.scatter(train_data, train_labels,c="r",label="Training data")
    # plot the testing data in yellow
    plt.scatter(test_data,test_labels,c="y",label="Testing Data")
    # plot the predictions in green
    plt.scatter(test_data, predictions, c="b", label="Predictions")
    plt.legend();
    
plot_predictions()

# %% [markdown]
# ### Evaluation our model prediction with regression evaluating metrices
#
# Depending on the problem we are working on , there will be so many evaluation metrics
#
#
# This problem is based upon the regression probelem So we are going to look for the regression evaluation metrics
#
#
# There are two regression evaluation metrices
#
# * 1. MAE - Mean Absolute Error
# * 2. MSE - Mean Square Error
# * 3. Huber - Combination of MAE and MSE

# %%
# Evaluate the model on the test dataset
model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 180ms/step - loss: 3.2206 - mae: 3.2206
# [3.220550537109375, 3.220550537109375]

# %%
# Calculate the mean absolute error
tf.metrics.mean_absolute_error(y_true=y_test,
                               y_pred=tf.squeeze(y_preds)) # we have reduced(squeezed) the dimension of the y_preds because 
                                                            #y_true and y_preds should have same shape to get MAE
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.2205505>

# %%
tf.metrics.mean_squared_error(y_test, tf.squeeze(y_preds))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.623042>

# %%
# create function to calculate the mean absolute error and mean squared error
def MAE(y_true=y_test, y_pred=y_preds):
    return tf.metrics.mean_absolute_error(y_true,tf.squeeze(y_pred)).numpy()

def MSE(y_true=y_test, y_pred=y_preds):
    return tf.metrics.mean_squared_error(y_true,tf.squeeze(y_pred)).numpy()

# %%
MAE() , MSE()
# Out:
# (3.2205505, 10.623042)

# %% [markdown]
# # Running Experiments to improve our model
#
# 1. **Get more data** - get more examples for your model to train on (more opportunities to learn patterns or relationships between features and labels.)
#
# 2. **Make your model larger( using a more complex model )** - this might come in the form of more layers or more hidden units in each layer
#
# 3. **Train for longer** -  give your model a more time to understand the patterns.

# %%
# let's take only one layers

# set random seed
tf.random.set_seed(42)

# create a model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# compile a model
model_1.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=["mae"])

# fit the model
model_1.fit(tf.expand_dims(x_train,axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 8ms/step - loss: 15.9024 - mae: 15.9024
# Epoch 2/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.2837 - mae: 11.2837
# Epoch 3/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.1074 - mae: 11.1074
# Epoch 4/100
# 2/2 [==============================] - 0s 16ms/step - loss: 9.2990 - mae: 9.2990
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.1677 - mae: 10.1677
# Epoch 6/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.4303 - mae: 9.4303
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.5704 - mae: 8.5704
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.0442 - mae: 9.0442
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 18.7517 - mae: 18.7517
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.1142 - mae: 10.1142
# Epoch 11/100
# ...

# %%
y_preds_1 = model_1.predict(x_test)
y_preds_1
# Out:
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021404287F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 56ms/step
# array([[53.57109 ],
#        [57.05633 ],
#        [60.541573],
#        [64.02681 ],
#        [67.512054],
#        [70.99729 ],
#        [74.48254 ],
#        [77.96777 ],
#        [81.45301 ],
#        [84.938255],
# ...

# %%
plot_predictions(predictions=y_preds_1)

# %%
# calculate the model evaluation metrices

mae_1 = MAE(y_pred=y_preds_1)
mse_1 = MSE(y_pred=y_preds_1)
mae_1 , mse_1
# Out:
# (19.002708, 363.7527)

# %%
# make model_2 by adding one more layers
# set random seed
tf.random.set_seed(42)

#create a model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])

# compile a model
model_2.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=["mae"])

# fit a model
model_2.fit(tf.expand_dims(x_train, axis=-1),y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 0s/step - loss: 27.4058 - mae: 27.4058
# Epoch 2/100
# 2/2 [==============================] - 0s 8ms/step - loss: 24.6339 - mae: 24.6339
# Epoch 3/100
# 2/2 [==============================] - 0s 8ms/step - loss: 29.8935 - mae: 29.8935
# Epoch 4/100
# 2/2 [==============================] - 0s 8ms/step - loss: 27.4055 - mae: 27.4055
# Epoch 5/100
# 2/2 [==============================] - 0s 9ms/step - loss: 14.9463 - mae: 14.9463
# Epoch 6/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.8819 - mae: 11.8819
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.1988 - mae: 11.1988
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.0910 - mae: 11.0910
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 40.4763 - mae: 40.4763
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 27.8688 - mae: 27.8688
# Epoch 11/100
# ...

# %%
y_preds_2 = model_2.predict(x_test)
# Out:
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002140A6F4D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 56ms/step

# %%
plot_predictions(predictions=y_preds_2)

# %%
# calculate the model_2 evaluation metrics
mae_2 = MAE(y_pred=y_preds_2)
mse_2 = MSE(y_pred=y_preds_2)
mae_2 , mse_2
# Out:
# (3.490824, 15.640057)

# %%
# now let's build the same model by using the 500 epochs LEts's Go!!!!!

# create a random seed
tf.random.set_seed(42)

# create a model
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])

# compile the model
model_3.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.SGD(),
             metrics=["mae"])

# fit a model
model_3.fit(tf.expand_dims(x_train,axis=-1),y_train,epochs=493)
# Out:
# Epoch 1/493
# 2/2 [==============================] - 0s 8ms/step - loss: 27.4058 - mae: 27.4058
# Epoch 2/493
# 2/2 [==============================] - 0s 15ms/step - loss: 24.6339 - mae: 24.6339
# Epoch 3/493
# 2/2 [==============================] - 0s 6ms/step - loss: 29.8935 - mae: 29.8935
# Epoch 4/493
# 2/2 [==============================] - 0s 6ms/step - loss: 27.4055 - mae: 27.4055
# Epoch 5/493
# 2/2 [==============================] - 0s 8ms/step - loss: 14.9463 - mae: 14.9463
# Epoch 6/493
# 2/2 [==============================] - 0s 8ms/step - loss: 11.8819 - mae: 11.8819
# Epoch 7/493
# 2/2 [==============================] - 0s 8ms/step - loss: 11.1988 - mae: 11.1988
# Epoch 8/493
# 2/2 [==============================] - 0s 8ms/step - loss: 11.0910 - mae: 11.0910
# Epoch 9/493
# 2/2 [==============================] - 0s 8ms/step - loss: 40.4763 - mae: 40.4763
# Epoch 10/493
# 2/2 [==============================] - 0s 8ms/step - loss: 27.8688 - mae: 27.8688
# Epoch 11/493
# ...

# %%
y_preds_3 = model_3.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 65ms/step

# %%
plot_predictions(predictions=y_preds_3)

# %%
# let's calculate the evaluation metrics for model_3

mae_3 = MAE(y_pred=y_preds_3)
mse_3 = MSE(y_pred=y_preds_3)
mae_3, mse_3
# Out:
# (12.825112, 171.133)

# %%
# let's create the model (by my way😎😎)

# create a random seed
tf.random.set_seed(42)

# create a model 
model_4 = tf.keras.Sequential([
    tf.keras.layers.Dense(7,input_shape=[1]),
    tf.keras.layers.Dense(14),
    tf.keras.layers.Dense(7),
    tf.keras.layers.Dense(1)
],name="model_4")

# compile a model
model_4.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
             metrics=["mae"])

# fit a model
model_4.fit(tf.expand_dims(x_train,axis=-1),y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 12ms/step - loss: 34.3484 - mae: 34.3484
# Epoch 2/100
# 2/2 [==============================] - 0s 8ms/step - loss: 20.3228 - mae: 20.3228
# Epoch 3/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.6259 - mae: 8.6259
# Epoch 4/100
# 2/2 [==============================] - 0s 8ms/step - loss: 14.8167 - mae: 14.8167
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 16.2017 - mae: 16.2017
# Epoch 6/100
# 2/2 [==============================] - 0s 8ms/step - loss: 12.6467 - mae: 12.6467
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.9592 - mae: 8.9592
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.9604 - mae: 8.9604
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.0297 - mae: 10.0297
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.4430 - mae: 8.4430
# Epoch 11/100
# ...

# %%
y_preds_4 = model_4.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 74ms/step

# %%
plot_predictions(predictions=y_preds_4)

# %%
mae_4 = MAE(y_pred=y_preds_4)
mse_4 = MSE(y_pred=y_preds_4)

# %%
### Compare the results of our experiments

import pandas as pd
model_dict = {"model" : ["model_1","model_2","model_3","model_4(😎)"],
             "MAE":[mae_1,mae_2,mae_3,mae_4],
             "MSE":[mse_1,mse_2,mse_3,mae_4]}

pd.DataFrame(model_dict)
# Out:
#         model        MAE         MSE
# 0     model_1  19.002708  363.752686
# 1     model_2   3.490824   15.640057
# 2     model_3  12.825112  171.132996
# 3  model_4(😎)   0.583126    0.583126

# %% [markdown]
# ### So our model_4 gives us the best predictions

# %%
plot_model(model_4,show_shapes=True) # 1 -> 7 -> 14 -> 7 -> 1

# %% [markdown]
# # Saving our model
#
# We can save the model which would be helpful for us to use this model directly whenever we need without actually training the model
#
# There are two types so we can save the modle in tensorflow
# 1. SaveModelFormate : https://www.tensorflow.org/tutorials/keras/save_and_load#savedmodel_format
# 2. HDF5 Format : https://www.tensorflow.org/tutorials/keras/save_and_load#hdf5_format

# %%
# save model using the savemodel format
model_4.save("saved-model/model_with_5_layers_best_model(savemodel_format)")
# Out:
# INFO:tensorflow:Assets written to: saved-model/model_with_5_layers_best_model(savemodel_format)\assets

# %%
# save model using the HDF5 format
model_4.save("saved-model/model_with_5_layers(HDF5).h5")

# %%
# load the model of savemodel format type
loaded_model_savemodel_format = tf.keras.models.load_model(filepath="saved-model/model_with_5_layers_best_model(savemodel_format)")

# %%
loaded_model_savemodel_format.predict([80])
# Out:
# 1/1 [==============================] - 0s 86ms/step
# array([[89.41687]], dtype=float32)

# %%
loaded_model_hdf5 = tf.keras.models.load_model(filepath="saved-model/model_with_5_layers(HDF5).h5")

# %%
loaded_model_hdf5.predict([80,90])
# Out:
# 1/1 [==============================] - 0s 88ms/step
# array([[89.41687],
#        [99.35788]], dtype=float32)
